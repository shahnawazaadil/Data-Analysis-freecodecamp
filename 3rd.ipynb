# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data=pd.read_csv("/Users/shahnawazaadil/Downloads/medical_examination-2.csv")

# %%
data
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 0          0     0       1       0
# ...

# %%
data['overweight']=(data['weight'])**2/(data['height'])

# %%
data
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
data['overweight']=(data['overweight']>25).astype(int)

# %%
data
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
data[['gluc','cholesterol']] = (data[['gluc','cholesterol']] > 1).astype(int)

# %%
data
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
cat=pd.melt(data,id_vars=['cardio'],value_vars=['active', 'alco', 'cholesterol', 'gluc', 'overweight', 'smoke'])

# %%
sns.catplot(data=cat,kind='count',hue='value',x='variable',col='cardio').set(ylabel='total')

# %%
data[~(data['ap_lo']<=data['ap_hi'])]
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 228      314  17489    2     183    98.0    160   1100            0     1
# 241      334  21932    2     157    60.0    160   1000            1     0
# 260      357  18217    1     150    83.0    140    800            0     0
# 329      458  23407    1     176    63.0    160   1000            1     1
# 345      482  18704    1     154    81.0    140   1000            1     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69771  99659  23330    1     167    81.0    160   1000            0     0
# 69872  99798  21808    1     152    56.0    160   1000            0     0
# 69878  99807  21239    2     168    95.0    160   1000            0     0
# 69885  99816  22417    2     166    78.0    170   1000            0     0
# 69967  99955  21416    2     168    63.0    140   1000            0     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %%
heat_map=data[(data['ap_lo']<=data['ap_hi'])&
     (data['height'] >= data['height'].quantile(0.025))&
    (data['height'] <= data['height'].quantile(0.975))&
    (data['weight'] >= data['weight'].quantile(0.025))&
    (data['weight'] <= data['weight'].quantile(0.975))]

# %%
corr=heat_map.corr()

# %%
mask=np.triu(corr)

# %%
sns.heatmap(corr,mask=mask,annot=True,fmt='0.1f',square=True)
# Out:
# <Axes: >
